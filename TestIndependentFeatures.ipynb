# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd

df_train = pd.read_csv('train_kaggle.csv')
df_test = pd.read_csv('sample_solution.csv')
Y = df_train['Label'].values

# %%
import numpy as np

dataframes = np.load('allData.npy', allow_pickle = True)
dataframes.shape
# Out:
# (18662,)

# %%
feature_length = [8,4,16,16,8,12,16,12,10]
selected_features = [True, True, True, True, True, False, False, False, False]
feature_pos = [[0,8],[8,12],[12,28],[28,44],[44,52],[52,64],[64,80],[80,92],[92,102]] 

def process(dfs, feature):
    data = []    
    length = feature_length[feature]   
    for df in dfs:
        out = np.zeros((df.shape[0],length))
        out[:,0:length] = df[:,feature_pos[feature,0]:feature_pos[feature,1]]

        data.append(out)                 
    return data

def pad_data(dfs):
    padsize = 500
    data = []
    for df in dfs:
        diff = padsize-df.shape[0]
        if diff >0:
            df = np.pad(df, [(0, diff), (0,0)], 'constant')
        else:
            df = df[-padsize:]
        data.append(df)
        
    data = np.stack(data)
    return data

# %%
def load_test_dataframe(id):
    test_data = np.load("test/test/{}.npy".format(id))
    return pd.DataFrame(data=test_data)

testdatas = []
for id in df_test['Id']:
    dfi = load_test_dataframe(id)
    testdatas.append(dfi.values)

# %%
XTrain = pad_data(dataframes)
XTest = pad_data(np.array(testdatas))

np.save('XTrain.npy', XTrain)
np.save('XTest.npy', XTrain)

# %%
XTrain.shape
# Out:
# (18662, 500, 102)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(XTrain, Y, test_size=0.1, random_state=42)

# %%
X_train.shape
# Out:
# (16795, 500, 102)

# %%
import tensorflow as tf
from tensorflow import keras

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.AUC(name='auc'),
]

def get_simple_conv(out):
    out = keras.layers.Conv1D(filters=6, kernel_size=5, padding='same', activation='relu')(out)
    out = keras.layers.MaxPooling1D(pool_size=2)(out)
    out = keras.layers.Dropout(0.4)(out)
    out = keras.layers.Conv1D(filters=16, kernel_size=5, padding='same', activation='relu')(out)
    out = keras.layers.MaxPooling1D(pool_size=2)(out)
    out = keras.layers.Dropout(0.4)(out)
    out = keras.layers.Flatten()(out)
    out = keras.layers.Dense(120, activation='relu')(out)
    out = keras.layers.Dense(84, activation='relu')(out)
    out = keras.layers.Dense(1, activation='sigmoid')(out)
    return out

inputs = keras.Input(shape=(X_train.shape[1], X_train.shape[2])) 
branch_outputs = []
for i in range(len(feature_length)):
    if selected_features[i] == False:
        continue
    # Slicing the ith channel:
    out = inputs[:,:,feature_pos[i][0]:feature_pos[i][1]]
    # Setting up your per-channel layers (replace with actual sub-models):
    out = get_simple_conv(out)
    branch_outputs.append(out)

'''
x = get_simple_conv(inputs)
branch_outputs.append(x)
'''

# Concatenating together the per-channel results:
out = keras.layers.Concatenate()(branch_outputs)
out = tf.math.reduce_mean(
    out,
    axis=1
)
out = tf.reshape(
    out,
    (-1, 1)
)
model = keras.Model(inputs=inputs, outputs=out)

# model.compile(loss='categorical_crossentropy',
#              optimizer='adam',
#              metrics=['accuracy'])

model.compile(
      optimizer=keras.optimizers.Adam(),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=METRICS)

# Take a look at the model summary
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 500, 102)]   0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_95 (T [(None, 500, 8)]     0           input_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_96 (T [(None, 500, 4)]     0           input_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_97 (T [(None, 500, 16)]    0           input_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_98 (T [(None, 500, 16)]    0           input_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_99 (T [(None, 500, 8)]     0           input_15[0][0]
# __________________________________________________________________________________________________
# conv1d_212 (Conv1D)             (None, 500, 6)       246         tf_op_layer_strided_slice_95[0][0
# __________________________________________________________________________________________________
# conv1d_214 (Conv1D)             (None, 500, 6)       126         tf_op_layer_strided_slice_96[0][0
# __________________________________________________________________________________________________
# conv1d_216 (Conv1D)             (None, 500, 6)       486         tf_op_layer_strided_slice_97[0][0
# __________________________________________________________________________________________________
# conv1d_218 (Conv1D)             (None, 500, 6)       486         tf_op_layer_strided_slice_98[0][0
# __________________________________________________________________________________________________
# conv1d_220 (Conv1D)             (None, 500, 6)       246         tf_op_layer_strided_slice_99[0][0
# __________________________________________________________________________________________________
# max_pooling1d_212 (MaxPooling1D (None, 250, 6)       0           conv1d_212[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_214 (MaxPooling1D (None, 250, 6)       0           conv1d_214[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_216 (MaxPooling1D (None, 250, 6)       0           conv1d_216[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_218 (MaxPooling1D (None, 250, 6)       0           conv1d_218[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_220 (MaxPooling1D (None, 250, 6)       0           conv1d_220[0][0]
# __________________________________________________________________________________________________
# dropout_214 (Dropout)           (None, 250, 6)       0           max_pooling1d_212[0][0]
# __________________________________________________________________________________________________
# dropout_216 (Dropout)           (None, 250, 6)       0           max_pooling1d_214[0][0]
# __________________________________________________________________________________________________
# dropout_218 (Dropout)           (None, 250, 6)       0           max_pooling1d_216[0][0]
# __________________________________________________________________________________________________
# dropout_220 (Dropout)           (None, 250, 6)       0           max_pooling1d_218[0][0]
# __________________________________________________________________________________________________
# dropout_222 (Dropout)           (None, 250, 6)       0           max_pooling1d_220[0][0]
# __________________________________________________________________________________________________
# conv1d_213 (Conv1D)             (None, 250, 16)      496         dropout_214[0][0]
# __________________________________________________________________________________________________
# conv1d_215 (Conv1D)             (None, 250, 16)      496         dropout_216[0][0]
# __________________________________________________________________________________________________
# conv1d_217 (Conv1D)             (None, 250, 16)      496         dropout_218[0][0]
# __________________________________________________________________________________________________
# conv1d_219 (Conv1D)             (None, 250, 16)      496         dropout_220[0][0]
# __________________________________________________________________________________________________
# conv1d_221 (Conv1D)             (None, 250, 16)      496         dropout_222[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_213 (MaxPooling1D (None, 125, 16)      0           conv1d_213[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_215 (MaxPooling1D (None, 125, 16)      0           conv1d_215[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_217 (MaxPooling1D (None, 125, 16)      0           conv1d_217[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_219 (MaxPooling1D (None, 125, 16)      0           conv1d_219[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_221 (MaxPooling1D (None, 125, 16)      0           conv1d_221[0][0]
# __________________________________________________________________________________________________
# dropout_215 (Dropout)           (None, 125, 16)      0           max_pooling1d_213[0][0]
# __________________________________________________________________________________________________
# dropout_217 (Dropout)           (None, 125, 16)      0           max_pooling1d_215[0][0]
# __________________________________________________________________________________________________
# dropout_219 (Dropout)           (None, 125, 16)      0           max_pooling1d_217[0][0]
# __________________________________________________________________________________________________
# dropout_221 (Dropout)           (None, 125, 16)      0           max_pooling1d_219[0][0]
# __________________________________________________________________________________________________
# dropout_223 (Dropout)           (None, 125, 16)      0           max_pooling1d_221[0][0]
# __________________________________________________________________________________________________
# flatten_106 (Flatten)           (None, 2000)         0           dropout_215[0][0]
# __________________________________________________________________________________________________
# flatten_107 (Flatten)           (None, 2000)         0           dropout_217[0][0]
# __________________________________________________________________________________________________
# flatten_108 (Flatten)           (None, 2000)         0           dropout_219[0][0]
# __________________________________________________________________________________________________
# flatten_109 (Flatten)           (None, 2000)         0           dropout_221[0][0]
# __________________________________________________________________________________________________
# flatten_110 (Flatten)           (None, 2000)         0           dropout_223[0][0]
# __________________________________________________________________________________________________
# dense_333 (Dense)               (None, 120)          240120      flatten_106[0][0]
# __________________________________________________________________________________________________
# dense_336 (Dense)               (None, 120)          240120      flatten_107[0][0]
# __________________________________________________________________________________________________
# dense_339 (Dense)               (None, 120)          240120      flatten_108[0][0]
# __________________________________________________________________________________________________
# dense_342 (Dense)               (None, 120)          240120      flatten_109[0][0]
# __________________________________________________________________________________________________
# dense_345 (Dense)               (None, 120)          240120      flatten_110[0][0]
# __________________________________________________________________________________________________
# dense_334 (Dense)               (None, 84)           10164       dense_333[0][0]
# __________________________________________________________________________________________________
# dense_337 (Dense)               (None, 84)           10164       dense_336[0][0]
# __________________________________________________________________________________________________
# dense_340 (Dense)               (None, 84)           10164       dense_339[0][0]
# __________________________________________________________________________________________________
# dense_343 (Dense)               (None, 84)           10164       dense_342[0][0]
# __________________________________________________________________________________________________
# dense_346 (Dense)               (None, 84)           10164       dense_345[0][0]
# __________________________________________________________________________________________________
# dense_335 (Dense)               (None, 1)            85          dense_334[0][0]
# __________________________________________________________________________________________________
# dense_338 (Dense)               (None, 1)            85          dense_337[0][0]
# __________________________________________________________________________________________________
# dense_341 (Dense)               (None, 1)            85          dense_340[0][0]
# __________________________________________________________________________________________________
# dense_344 (Dense)               (None, 1)            85          dense_343[0][0]
# __________________________________________________________________________________________________
# dense_347 (Dense)               (None, 1)            85          dense_346[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 5)            0           dense_335[0][0]
#                                                                  dense_338[0][0]
#                                                                  dense_341[0][0]
#                                                                  dense_344[0][0]
#                                                                  dense_347[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_5 (TensorFlowO [(None,)]            0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_2 (TensorFl [(None, 1)]          0           tf_op_layer_Mean_5[0][0]
# ==================================================================================================
# Total params: 1,255,915
# Trainable params: 1,255,915
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %%
from tensorflow.keras.utils import to_categorical

EPOCHS = 100
baseline_history = model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    callbacks = [early_stopping],
    validation_data=(X_val, y_val))
# Out:
# Train on 16795 samples, validate on 1867 samples
# Epoch 1/100
# 16795/16795 [==============================] - 44s 3ms/sample - loss: 0.3463 - accuracy: 0.8471 - auc: 0.9201 - val_loss: 0.2931 - val_accuracy: 0.8677 - val_auc: 0.9528
# Epoch 2/100
# 16795/16795 [==============================] - 42s 2ms/sample - loss: 0.2858 - accuracy: 0.8684 - auc: 0.9495 - val_loss: 0.2591 - val_accuracy: 0.8848 - val_auc: 0.9637
# Epoch 3/100
# 16795/16795 [==============================] - 37s 2ms/sample - loss: 0.2594 - accuracy: 0.8808 - auc: 0.9594 - val_loss: 0.2411 - val_accuracy: 0.8827 - val_auc: 0.9686
# Epoch 4/100
# 16795/16795 [==============================] - 35s 2ms/sample - loss: 0.2491 - accuracy: 0.8874 - auc: 0.9630 - val_loss: 0.2362 - val_accuracy: 0.8907 - val_auc: 0.9699
# Epoch 5/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.2399 - accuracy: 0.8910 - auc: 0.9660 - val_loss: 0.2245 - val_accuracy: 0.8950 - val_auc: 0.9717
# Epoch 6/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.2312 - accuracy: 0.8978 - auc: 0.9689 - val_loss: 0.2198 - val_accuracy: 0.9020 - val_auc: 0.9737
# Epoch 7/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.2263 - accuracy: 0.9006 - auc: 0.9707 - val_loss: 0.2226 - val_accuracy: 0.8977 - val_auc: 0.9731
# Epoch 8/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.2180 - accuracy: 0.9047 - auc: 0.9734 - val_loss: 0.2200 - val_accuracy: 0.8956 - val_auc: 0.9746
# Epoch 9/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.2108 - accuracy: 0.9071 - auc: 0.9752 - val_loss: 0.2133 - val_accuracy: 0.8998 - val_auc: 0.9745
# Epoch 10/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.2083 - accuracy: 0.9093 - auc: 0.9757 - val_loss: 0.2166 - val_accuracy: 0.9057 - val_auc: 0.9747
# Epoch 11/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.2050 - accuracy: 0.9112 - auc: 0.9768 - val_loss: 0.2125 - val_accuracy: 0.9031 - val_auc: 0.9744
# Epoch 12/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.2009 - accuracy: 0.9141 - auc: 0.9778 - val_loss: 0.2092 - val_accuracy: 0.9057 - val_auc: 0.9754
# Epoch 13/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.1967 - accuracy: 0.9178 - auc: 0.9787 - val_loss: 0.2114 - val_accuracy: 0.9068 - val_auc: 0.9754
# Epoch 14/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1935 - accuracy: 0.9193 - auc: 0.9796 - val_loss: 0.1966 - val_accuracy: 0.9106 - val_auc: 0.9783
# Epoch 15/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.1854 - accuracy: 0.9210 - auc: 0.9812 - val_loss: 0.2015 - val_accuracy: 0.9106 - val_auc: 0.9774
# Epoch 16/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1851 - accuracy: 0.9226 - auc: 0.9812 - val_loss: 0.1948 - val_accuracy: 0.9122 - val_auc: 0.9776
# Epoch 17/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1797 - accuracy: 0.9256 - auc: 0.9821 - val_loss: 0.1935 - val_accuracy: 0.9122 - val_auc: 0.9784
# Epoch 18/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.1781 - accuracy: 0.9270 - auc: 0.9825 - val_loss: 0.1986 - val_accuracy: 0.9084 - val_auc: 0.9785
# Epoch 19/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.1753 - accuracy: 0.9308 - auc: 0.9835 - val_loss: 0.1958 - val_accuracy: 0.9100 - val_auc: 0.9780
# Epoch 20/100
# 16795/16795 [==============================] - 33s 2ms/sample - loss: 0.1734 - accuracy: 0.9296 - auc: 0.9836 - val_loss: 0.1919 - val_accuracy: 0.9079 - val_auc: 0.9779
# Epoch 21/100
# 16795/16795 [==============================] - 33s 2ms/sample - loss: 0.1799 - accuracy: 0.9327 - auc: 0.9834 - val_loss: 0.2057 - val_accuracy: 0.9122 - val_auc: 0.9771
# Epoch 22/100
# 16795/16795 [==============================] - 33s 2ms/sample - loss: 0.1723 - accuracy: 0.9329 - auc: 0.9841 - val_loss: 0.1979 - val_accuracy: 0.9089 - val_auc: 0.9788
# Epoch 23/100
# 16795/16795 [==============================] - 31s 2ms/sample - loss: 0.1690 - accuracy: 0.9315 - auc: 0.9846 - val_loss: 0.1976 - val_accuracy: 0.9089 - val_auc: 0.9783
# Epoch 24/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1667 - accuracy: 0.9335 - auc: 0.9851 - val_loss: 0.1908 - val_accuracy: 0.9116 - val_auc: 0.9793
# Epoch 25/100
# 16795/16795 [==============================] - 38s 2ms/sample - loss: 0.1656 - accuracy: 0.9357 - auc: 0.9851 - val_loss: 0.1935 - val_accuracy: 0.9181 - val_auc: 0.9792
# Epoch 26/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1652 - accuracy: 0.9366 - auc: 0.9853 - val_loss: 0.1931 - val_accuracy: 0.9154 - val_auc: 0.9783
# Epoch 27/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1597 - accuracy: 0.9390 - auc: 0.9862 - val_loss: 0.1871 - val_accuracy: 0.9143 - val_auc: 0.9799
# Epoch 28/100
# 16795/16795 [==============================] - 39s 2ms/sample - loss: 0.1596 - accuracy: 0.9396 - auc: 0.9862 - val_loss: 0.1901 - val_accuracy: 0.9181 - val_auc: 0.9791
# Epoch 29/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1604 - accuracy: 0.9390 - auc: 0.9859 - val_loss: 0.1972 - val_accuracy: 0.9063 - val_auc: 0.9787
# Epoch 30/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1601 - accuracy: 0.9411 - auc: 0.9862 - val_loss: 0.1981 - val_accuracy: 0.9111 - val_auc: 0.9782
# Epoch 31/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1568 - accuracy: 0.9416 - auc: 0.9867 - val_loss: 0.1888 - val_accuracy: 0.9122 - val_auc: 0.9792
# Epoch 32/100
# 16795/16795 [==============================] - 32s 2ms/sample - loss: 0.1539 - accuracy: 0.9422 - auc: 0.9871 - val_loss: 0.1888 - val_accuracy: 0.9127 - val_auc: 0.9804
# Epoch 33/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1516 - accuracy: 0.9421 - auc: 0.9876 - val_loss: 0.1882 - val_accuracy: 0.9122 - val_auc: 0.9788
# Epoch 34/100
# 16795/16795 [==============================] - 37s 2ms/sample - loss: 0.1508 - accuracy: 0.9425 - auc: 0.9877 - val_loss: 0.1908 - val_accuracy: 0.9122 - val_auc: 0.9790
# Epoch 35/100
# 16795/16795 [==============================] - 33s 2ms/sample - loss: 0.1512 - accuracy: 0.9439 - auc: 0.9880 - val_loss: 0.1875 - val_accuracy: 0.9143 - val_auc: 0.9804
# Epoch 36/100
# 16795/16795 [==============================] - 37s 2ms/sample - loss: 0.1519 - accuracy: 0.9436 - auc: 0.9871 - val_loss: 0.1919 - val_accuracy: 0.9127 - val_auc: 0.9804
# Epoch 37/100
# 16795/16795 [==============================] - 42s 3ms/sample - loss: 0.1503 - accuracy: 0.9457 - auc: 0.9877 - val_loss: 0.1841 - val_accuracy: 0.9164 - val_auc: 0.9805
# Epoch 38/100
# 16795/16795 [==============================] - 34s 2ms/sample - loss: 0.1460 - accuracy: 0.9468 - auc: 0.9885 - val_loss: 0.1859 - val_accuracy: 0.9138 - val_auc: 0.9815
# Epoch 39/100
# 16795/16795 [==============================] - 35s 2ms/sample - loss: 0.1434 - accuracy: 0.9478 - auc: 0.9889 - val_loss: 0.1795 - val_accuracy: 0.9175 - val_auc: 0.9809
# Epoch 40/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1441 - accuracy: 0.9475 - auc: 0.9886 - val_loss: 0.1872 - val_accuracy: 0.9164 - val_auc: 0.9800
# Epoch 41/100
# 16795/16795 [==============================] - 34s 2ms/sample - loss: 0.1442 - accuracy: 0.9490 - auc: 0.9885 - val_loss: 0.1948 - val_accuracy: 0.9154 - val_auc: 0.9786
# Epoch 42/100
# 16795/16795 [==============================] - 37s 2ms/sample - loss: 0.1454 - accuracy: 0.9477 - auc: 0.9886 - val_loss: 0.1937 - val_accuracy: 0.9191 - val_auc: 0.9800
# Epoch 43/100
# 16795/16795 [==============================] - 35s 2ms/sample - loss: 0.1413 - accuracy: 0.9478 - auc: 0.9890 - val_loss: 0.1938 - val_accuracy: 0.9159 - val_auc: 0.9791
# Epoch 44/100
# 16795/16795 [==============================] - 34s 2ms/sample - loss: 0.1410 - accuracy: 0.9505 - auc: 0.9893 - val_loss: 0.2024 - val_accuracy: 0.9159 - val_auc: 0.9770
# Epoch 45/100
# 16795/16795 [==============================] - 39s 2ms/sample - loss: 0.1416 - accuracy: 0.9490 - auc: 0.9892 - val_loss: 0.2188 - val_accuracy: 0.9202 - val_auc: 0.9747
# Epoch 46/100
# 16795/16795 [==============================] - 37s 2ms/sample - loss: 0.1423 - accuracy: 0.9488 - auc: 0.9888 - val_loss: 0.1889 - val_accuracy: 0.9159 - val_auc: 0.9782
# Epoch 47/100
# 16795/16795 [==============================] - 36s 2ms/sample - loss: 0.1414 - accuracy: 0.9505 - auc: 0.9890 - val_loss: 0.1911 - val_accuracy: 0.9154 - val_auc: 0.9784
# Epoch 48/100
# 16768/16795 [============================>.] - ETA: 0s - loss: 0.1400 - accuracy: 0.9515 - auc: 0.9890Restoring model weights from the end of the best epoch.
# 16795/16795 [==============================] - 35s 2ms/sample - loss: 0.1400 - accuracy: 0.9514 - auc: 0.9889 - val_loss: 0.1971 - val_accuracy: 0.9223 - val_auc: 0.9778
# Epoch 00048: early stopping

# %%
YTest = model.predict(XTest)
df_test['Predicted'] = YTest[:, 0]
df_test
# Out:
#         Id  Predicted
# 0        0   0.999736
# 1        1   0.961501
# 2        2   0.001920
# 3        3   0.970701
# 4        4   0.451361
# 5        5   0.137144
# 6        6   0.000174
# 7        7   0.645911
# 8        8   0.999999
# 9        9   1.000000
# 10      10   0.195796
# 11      11   0.999989
# 12      12   0.999644
# 13      13   0.477238
# 14      14   0.000130
# 15      15   0.000002
# 16      16   0.109369
# 17      17   0.971088
# 18      18   0.220638
# 19      19   0.013637
# 20      20   0.800000
# 21      21   0.013734
# 22      22   0.105663
# 23      23   0.999960
# 24      24   0.999948
# 25      25   0.013633
# 26      26   0.112415
# 27      27   0.000117
# 28      28   0.824356
# 29      29   0.113007
# ...    ...        ...
# 6021  6021   0.200215
# 6022  6022   0.108139
# 6023  6023   0.596071
# 6024  6024   0.999987
# 6025  6025   0.808326
# 6026  6026   0.033943
# 6027  6027   0.799417
# 6028  6028   0.999997
# 6029  6029   0.000231
# 6030  6030   1.000000
# 6031  6031   0.885840
# 6032  6032   0.999948
# 6033  6033   0.798769
# 6034  6034   0.105663
# 6035  6035   0.009246
# 6036  6036   0.013692
# 6037  6037   1.000000
# 6038  6038   0.110656
# 6039  6039   0.999948
# 6040  6040   0.000117
# 6041  6041   0.200855
# 6042  6042   0.013671
# 6043  6043   0.000179
# 6044  6044   0.013948
# 6045  6045   0.781807
# 6046  6046   0.682677
# 6047  6047   0.969787
# 6048  6048   0.000117
# 6049  6049   0.800015
# 6050  6050   0.000201
#
# [6051 rows x 2 columns]

# %%
df_test.to_csv('test.csv', index=False)
